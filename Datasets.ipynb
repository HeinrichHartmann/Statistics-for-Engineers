# %%
# !ls DataSets/*.csv
# Out:
# DataSets/cpu.out.csv		       DataSets/HistogramExample_quotes.csv
# DataSets/dc1cpu.csv		       DataSets/LogDB.csv
# DataSets/dtrace_histogram_a.txt.csv    DataSets/LogDB_full.csv
# DataSets/dtrace_histogram_b.txt.csv    DataSets/LogDB_head.csv
# DataSets/HistogramAPI_10.csv	       DataSets/MobileRequestRate.csv
# DataSets/HistogramAPI_15.csv	       DataSets/ReqLoad.csv
# DataSets/HistogramAPI.csv	       DataSets/ReqMultiNode.csv
# DataSets/HistogramAPI_samples_10.csv   DataSets/ReqMultiNode_long.csv
# DataSets/HistogramAPI_samples_15.csv   DataSets/ReqRate4w.csv
# DataSets/HistogramAPI_samples_1.csv    DataSets/ReqRateTrend.csv
# DataSets/HistogramAPI_samples_5.csv    DataSets/RequestRates.csv
# DataSets/HistogramAPI_samples_all.csv  DataSets/WebLatency.csv
# DataSets/HistogramExample.csv

# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
for fn in

# %%
fn = "DataSets/dc1cpu.csv"
# !csvlook -H $fn  | head
# Out:
# |-------------+-------------------+-------------------+-------------------+-------------------+-------------------+--------------------|
# |  column1    | column2           | column3           | column4           | column5           | column6           | column7            |
# |-------------+-------------------+-------------------+-------------------+-------------------+-------------------+--------------------|
# |  1430033280 | 0.466690003871918 | 0.449970006942749 | 0.5               | 0.516683876514435 | 0.515455365180969 | 0.500216782093048  |
# |  1430033340 | 0.46674445271492  | 0.466666668653488 | 0.500008344650269 | 0.516253650188446 | 0.534678936004639 | 0.499875038862228  |
# |  1430033400 | 3.18041801452637  | 2.71607828140259  | 6.02768754959106  | 5.95377063751221  | 0.548345804214478 | 0.599810063838959  |
# |  1430033460 | 3.40147399902344  | 6.5851993560791   | 3.97570967674255  | 3.18354558944702  | 6.15220022201538  | 5.7498083114624    |
# |  1430033520 | 0.466830044984817 | 0.58323609828949  | 0.483365565538406 | 0.516658067703247 | 3.1507351398468   | 3.78554153442383   |
# |  1430033580 | 0.466658890247345 | 0.566628873348236 | 0.499875038862228 | 0.516632199287415 | 1.16660833358765  | 0.499916672706604  |
# |  1430033640 | 1.24981248378754  | 0.583012700080872 | 0.500125050544739 | 0.500066697597504 | 0.899835050106049 | 0.500016689300537  |

# %%
plt.figure(figsize=(20,2))
X = np.genfromtxt("DataSets/dc1cpu.csv", delimiter=',')
plt.plot(X[:500,0], X[:500,1:])
# Out:
# [<matplotlib.lines.Line2D at 0x7fe4cc785490>,
#  <matplotlib.lines.Line2D at 0x7fe4cc785890>,
#  <matplotlib.lines.Line2D at 0x7fe4cc785210>,
#  <matplotlib.lines.Line2D at 0x7fe4cc785390>,
#  <matplotlib.lines.Line2D at 0x7fe4cc7853d0>,
#  <matplotlib.lines.Line2D at 0x7fe4cd3d9450>]

# %%
plt.figure(figsize=(20,2))
plt.hist(X[:500,1], bins=300, range=(0,10))
plt.show()
